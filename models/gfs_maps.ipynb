# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path("../src")))

from gfs import GfsFetcher, GribReader, MapBuilder
from gfs.products import MLCape, ThetaEProduct, ConvectionProduct, DailyConvectionProduct, MslpProduct, ConvectivePrecipProduct

# %%
DATA_DIR = Path("../data/gfs")
N_FILES = 24

# %%
fetcher = GfsFetcher(output_dir=DATA_DIR)
file_paths = fetcher.fetch_latest(n_files=N_FILES, clear_first=True)
print(f"Pobrano {len(file_paths)} plików GRIB.")
# Out:
# Pobrano 24 plików GRIB.

# %%
# Sprawdz dostepne parametry w pierwszym pliku GRIB
from gfs.reader import GribReader

first_file = sorted(file_paths)[0]
df = GribReader(first_file).scan_file()
print(f"Plik: {first_file.name}")
df.sort_values(["typeOfLevel", "parameter"]).reset_index(drop=True)

# %%
# Generuj mapy dla wszystkich krokow prognozy
product = ConvectivePrecipProduct()

for fp in sorted(file_paths):
    product.plot(fp, save=True, show=False)

print(f"Wygenerowano {len(file_paths)} map.")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\projects\mapymeteo\.venv\Lib\site-packages\xarray\core\dataset.py:1248, in Dataset._construct_dataarray(self, name)
#    1247 try:
# -> 1248     variable = self._variables[name]
#    1249 except KeyError:
#
# KeyError: 'acpcp'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File c:\projects\mapymeteo\.venv\Lib\site-packages\xarray\core\dataset.py:1355, in Dataset.__getitem__(self, key)
#    1354 try:
# -> 1355     return self._construct_dataarray(key)
#    1356 except KeyError as e:
#
# File c:\projects\mapymeteo\.venv\Lib\site-packages\xarray\core\dataset.py:1250, in Dataset._construct_dataarray(self, name)
#    1249 except KeyError:
# -> 1250     _, name, variable = _get_virtual_variable(self._variables, name, self.sizes)
#    1252 needed_dims = set(variable.dims)
#
# File c:\projects\mapymeteo\.venv\Lib\site-packages\xarray\core\dataset_utils.py:79, in _get_virtual_variable(variables, key, dim_sizes)
#      78 if len(split_key) != 2:
# ---> 79     raise KeyError(key)
#      81 ref_name, var_name = split_key
#
# KeyError: 'acpcp'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 5
#       1 # Generuj mapy dla wszystkich krokow prognozy
#       2 product = ConvectivePrecipProduct()
#       3
#       4 for fp in sorted(file_paths):
# ----> 5     product.plot(fp, save=True, show=False)
#       6
#       7 print(f"Wygenerowano {len(file_paths)} map.")
#
# File c:\projects\mapymeteo\models\..\src\gfs\products\base.py:101, in GfsProduct.plot(self, file_path, save, show, output_dir)
#      91 """Render the product and optionally save PNG+JSON and/or display it.
#      92
#      93 Parameters
#    (...)     98 output_dir : directory for output files; defaults to img/gfs/
#      99 """
#     100 file_path = Path(file_path)
# --> 101 self._render(file_path)
#     103 if save:
#     104     out_dir = Path(output_dir) if output_dir else _DEFAULT_IMG_DIR
#
# File c:\projects\mapymeteo\models\..\src\gfs\products\convection.py:89, in ConvectivePrecipProduct._render(self, file_path)
#      86 reader = GribReader(file_path)
#      88 # Accumulated convective precip [kg/m² == mm]
# ---> 89 acpcp = reader.get_parameter("acpcp", "surface", 0, step_type="accum")
#      91 # Storm motion vectors — GFS stores these at the 0–6000 m layer
#      92 # typeOfLevel='heightAboveGroundLayer', level=6000 (top of layer in cfgrib)
#      93 try:
#
# File c:\projects\mapymeteo\models\..\src\gfs\reader.py:46, in GribReader.get_parameter(self, parameter, type_of_level, level, step_type)
#      39     filter_keys["stepType"] = step_type
#      41 ds = xr.open_dataset(
#      42     self.file_path,
#      43     engine="cfgrib",
#      44     filter_by_keys=filter_keys,
#      45 )
# ---> 46 return ds[parameter]
#
# File c:\projects\mapymeteo\.venv\Lib\site-packages\xarray\core\dataset.py:1368, in Dataset.__getitem__(self, key)
#    1366         if isinstance(key, tuple):
#    1367             message += f"\nHint: use a list to select multiple variables, for example `ds[{list(key)}]`"
# -> 1368         raise KeyError(message) from e
#    1370 if utils.iterable_of_hashable(key):
#    1371     return self._copy_listed(key)
#
# KeyError: "No variable named 'acpcp'. Variables on the dataset include []"
